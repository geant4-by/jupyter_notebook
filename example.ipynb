# %%
import numpy as np

data_column = np.loadtxt('data.dat')

# %%
data_column
# Out:
# array([[-9.50000e-01,  9.98147e-01,  1.00000e+00],
#        [-8.50000e-01,  1.72419e+00,  2.00000e+00],
#        [-7.50000e-01,  7.56603e-01,  1.00000e+00],
#        [-6.50000e-01,  1.33641e+00,  2.00000e+00],
#        [-5.50000e-01,  2.52195e+00,  4.00000e+00],
#        [-4.50000e-01,  1.06950e+00,  2.00000e+00],
#        [-3.50000e-01,  4.60361e-01,  1.00000e+00],
#        [-2.50000e-01,  0.00000e+00,  0.00000e+00],
#        [-1.50000e-01,  9.64364e-01,  3.00000e+00],
#        [-5.00000e-02,  0.00000e+00,  0.00000e+00],
#        [ 5.00000e-02,  0.00000e+00,  0.00000e+00],
#        [ 1.50000e-01,  1.77190e-01,  1.00000e+00],
#        [ 2.50000e-01,  1.37812e+00,  1.00000e+01],
#        [ 3.50000e-01,  1.81957e+00,  1.70000e+01],
#        [ 4.50000e-01,  1.56222e+00,  2.20000e+01],
#        [ 5.50000e-01,  1.34905e+00,  2.70000e+01],
#        [ 6.50000e-01,  1.53470e+00,  5.20000e+01],
#        [ 7.50000e-01,  1.41167e+00,  9.40000e+01],
#        [ 8.50000e-01,  1.53517e+00,  2.92000e+02],
#        [ 9.50000e-01,  1.61765e+00,  9.94130e+04]])

# %%
col0 = data_column[:, 0]
col1 = data_column[:, 1]

# %%
col1
# Out:
# array([0.998147, 1.72419 , 0.756603, 1.33641 , 2.52195 , 1.0695  ,
#        0.460361, 0.      , 0.964364, 0.      , 0.      , 0.17719 ,
#        1.37812 , 1.81957 , 1.56222 , 1.34905 , 1.5347  , 1.41167 ,
#        1.53517 , 1.61765 ])

# %%
import matplotlib.pyplot as plt
plt.hist(col1, bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Data')
plt.show()

# %%
a = np.vstack((col0, col1)).T
a
# Out:
# array([[-0.95    ,  0.998147],
#        [-0.85    ,  1.72419 ],
#        [-0.75    ,  0.756603],
#        [-0.65    ,  1.33641 ],
#        [-0.55    ,  2.52195 ],
#        [-0.45    ,  1.0695  ],
#        [-0.35    ,  0.460361],
#        [-0.25    ,  0.      ],
#        [-0.15    ,  0.964364],
#        [-0.05    ,  0.      ],
#        [ 0.05    ,  0.      ],
#        [ 0.15    ,  0.17719 ],
#        [ 0.25    ,  1.37812 ],
#        [ 0.35    ,  1.81957 ],
#        [ 0.45    ,  1.56222 ],
#        [ 0.55    ,  1.34905 ],
#        [ 0.65    ,  1.5347  ],
#        [ 0.75    ,  1.41167 ],
#        [ 0.85    ,  1.53517 ],
#        [ 0.95    ,  1.61765 ]])

# %%
np.savetxt('data2.txt', a, fmt="%.6f", delimiter=',')
